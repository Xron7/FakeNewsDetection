# %%
import pandas as pd

# %%
PATH = 'twitter15/'

# %%
df = pd.read_csv(PATH + 'dataset_enhanced.csv')

# %%
df.head()
# Out:
#              tweet_id                                              tweet  \
# 0  731166399389962242  🔥ca kkk grand wizard 🔥 endorses @hillaryclinto...
# 1  714598641827246081  an open letter to trump voters from his top st...
# 2  691809004356501505  america is a nation of second chances —@potus ...
# 3  693204708933160960  brandon marshall visits and offers advice, sup...
# 4  551099691702956032  rip elly may clampett: so sad to learn #beverl...
#
#         label     poster  num_rt  depth_max  depth_avg  time_total  \
# 0  unverified  431917957     147          3   1.220690   171903.50
# 1  unverified   94215989      95          3   1.210526   101483.42
# 2   non-rumor   30313925     634          3   1.060222    27374.98
# 3   non-rumor    2557521     325          5   1.361963    14027.32
# 4        true    2883841     119          2   1.050420      610.92
#
#        time_avg  rts_half_life  ...  rts_under_1440_min  length  num_words  \
# ...
